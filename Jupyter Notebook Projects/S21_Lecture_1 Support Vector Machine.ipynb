# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:/Machine Learning/Complete Machine Learning with Python/Data Files/4. ST Academy - SVM resource files/Movie_regression.csv", header=0)

# %%
df.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# 0            7.995           7.94         527367          YES      109.60
# 1            7.470           7.44         494055           NO      146.64
# 2            7.515           7.44         547051           NO      147.88
# 3            7.020           8.26         516279          YES      185.36
# 4            7.070           8.26         531448           NO      176.48
#
#    Twitter_hastags     Genre  Avg_age_actors  Num_multiplex  Collection
# 0          223.840  Thriller              23            494       48000
# 1          243.456     Drama              42            462       43200
# 2         2022.400    Comedy              38            458       69400
# 3          225.344     Drama              45            472       66800
# 4          225.792     Drama              55            395       72400

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Marketing expense    506 non-null    float64
#  1   Production expense   506 non-null    float64
#  2   Multiplex coverage   506 non-null    float64
#  3   Budget               506 non-null    float64
#  4   Movie_length         506 non-null    float64
#  5   Lead_ Actor_Rating   506 non-null    float64
#  6   Lead_Actress_rating  506 non-null    float64
#  7   Director_rating      506 non-null    float64
#  8   Producer_rating      506 non-null    float64
#  9   Critic_rating        506 non-null    float64
#  10  Trailer_views        506 non-null    int64
#  11  3D_available         506 non-null    object
#  12  Time_taken           494 non-null    float64
#  13  Twitter_hastags      506 non-null    float64
#  14  Genre                506 non-null    object
#  15  Avg_age_actors       506 non-null    int64
#  16  Num_multiplex        506 non-null    int64
#  17  Collection           506 non-null    int64
# dtypes: float64(12), int64(4), object(2)
# memory usage: 71.3+ KB

# %% [markdown]
# ## Missing value imputation

# %%
df['Time_taken'].mean()
# Out:
# 157.3914979757085

# %%
df['Time_taken'].fillna(value = df['Time_taken'].mean(), inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Marketing expense    506 non-null    float64
#  1   Production expense   506 non-null    float64
#  2   Multiplex coverage   506 non-null    float64
#  3   Budget               506 non-null    float64
#  4   Movie_length         506 non-null    float64
#  5   Lead_ Actor_Rating   506 non-null    float64
#  6   Lead_Actress_rating  506 non-null    float64
#  7   Director_rating      506 non-null    float64
#  8   Producer_rating      506 non-null    float64
#  9   Critic_rating        506 non-null    float64
#  10  Trailer_views        506 non-null    int64
#  11  3D_available         506 non-null    object
#  12  Time_taken           506 non-null    float64
#  13  Twitter_hastags      506 non-null    float64
#  14  Genre                506 non-null    object
#  15  Avg_age_actors       506 non-null    int64
#  16  Num_multiplex        506 non-null    int64
#  17  Collection           506 non-null    int64
# dtypes: float64(12), int64(4), object(2)
# memory usage: 71.3+ KB

# %% [markdown]
# ## Dummy Variable Creation

# %%
df.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# 0            7.995           7.94         527367          YES      109.60
# 1            7.470           7.44         494055           NO      146.64
# 2            7.515           7.44         547051           NO      147.88
# 3            7.020           8.26         516279          YES      185.36
# 4            7.070           8.26         531448           NO      176.48
#
#    Twitter_hastags     Genre  Avg_age_actors  Num_multiplex  Collection
# 0          223.840  Thriller              23            494       48000
# 1          243.456     Drama              42            462       43200
# 2         2022.400    Comedy              38            458       69400
# 3          225.344     Drama              45            472       66800
# 4          225.792     Drama              55            395       72400

# %%
df = pd.get_dummies(df, columns = ["3D_available", "Genre"], drop_first = True)

# %%
df.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views  Time_taken  Twitter_hastags  \
# 0            7.995           7.94         527367      109.60          223.840
# 1            7.470           7.44         494055      146.64          243.456
# 2            7.515           7.44         547051      147.88         2022.400
# 3            7.020           8.26         516279      185.36          225.344
# 4            7.070           8.26         531448      176.48          225.792
#
#    Avg_age_actors  Num_multiplex  Collection  3D_available_YES  Genre_Comedy  \
# 0              23            494       48000              True         False
# 1              42            462       43200             False         False
# 2              38            458       69400             False          True
# 3              45            472       66800              True         False
# 4              55            395       72400             False         False
#
#    Genre_Drama  Genre_Thriller
# 0        False            True
# 1         True           False
# 2        False           False
# 3         True           False
# 4         True           False

# %%
X = df.loc[:,df.columns!="Collection"]
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
X.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views  Time_taken  Twitter_hastags  \
# 0            7.995           7.94         527367      109.60          223.840
# 1            7.470           7.44         494055      146.64          243.456
# 2            7.515           7.44         547051      147.88         2022.400
# 3            7.020           8.26         516279      185.36          225.344
# 4            7.070           8.26         531448      176.48          225.792
#
#    Avg_age_actors  Num_multiplex  3D_available_YES  Genre_Comedy  Genre_Drama  \
# 0              23            494              True         False        False
# 1              42            462             False         False         True
# 2              38            458             False          True        False
# 3              45            472              True         False         True
# 4              55            395             False         False         True
#
#    Genre_Thriller
# 0            True
# 1           False
# 2           False
# 3           False
# 4           False

# %%
X.shape
# Out:
# (506, 19)

# %%
y = df["Collection"]
type(y)
# Out:
# pandas.core.series.Series

# %%
y.head()
# Out:
# 0    48000
# 1    43200
# 2    69400
# 3    66800
# 4    72400
# Name: Collection, dtype: int64

# %%
y.shape
# Out:
# (506,)

# %% [markdown]
# ## Test Train Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
X_train.head()
# Out:
#      Marketing expense  Production expense  Multiplex coverage     Budget  \
# 220            27.1618               67.40               0.493  38612.805
# 71             23.1752               76.62               0.587  33113.355
# 240            22.2658               64.86               0.572  38312.835
# 6              21.7658               70.74               0.476  33396.660
# 417           538.8120               91.20               0.321  29463.720
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 220         162.0               8.485                8.640            8.485
# 71           91.0               7.280                7.400            7.290
# 240         127.8               6.755                6.935            6.800
# 6           140.1               7.065                7.265            7.150
# 417         162.6               9.135                9.305            9.095
#
#      Producer_rating  Critic_rating  Trailer_views  Time_taken  \
# 220            8.670           8.52         480270      174.68
# 71             7.455           8.16         491978      200.68
# 240            6.840           8.68         470107      204.80
# 6              7.400           8.96         459241      139.16
# 417            9.165           6.96         302776      172.16
#
#      Twitter_hastags  Avg_age_actors  Num_multiplex  3D_available_YES  \
# 220          224.272              23            536             False
# 71           263.472              46            400             False
# 240          224.320              24            387              True
# 6            243.664              41            522              True
# 417          301.664              60            589              True
#
#      Genre_Comedy  Genre_Drama  Genre_Thriller
# 220         False        False            True
# 71          False        False           False
# 240          True        False           False
# 6           False        False            True
# 417         False        False           False

# %% [markdown]
# ## Standardizing Data

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler().fit(X_train)

# %%
X_train_std = sc.transform(X_train)

# %%
X_test_std = sc.transform(X_test)

# %%
X_test_std
# Out:
# array([[-0.40835869, -1.12872913,  0.83336883, ...,  1.50268577,
#         -0.48525664, -0.75225758],
#        [ 0.71925111,  0.9988844 , -0.65283979, ...,  1.50268577,
#         -0.48525664, -0.75225758],
#        [-0.40257488,  0.39610829,  0.05115377, ...,  1.50268577,
#         -0.48525664, -0.75225758],
#        ...,
#        [-0.3982601 , -0.85812418,  0.89420778, ..., -0.66547513,
#         -0.48525664,  1.3293319 ],
#        [-0.39934279, -0.07637654,  0.58132175, ...,  1.50268577,
#         -0.48525664, -0.75225758],
#        [-0.40088071, -0.36702631,  0.31189212, ..., -0.66547513,
#         -0.48525664, -0.75225758]])

# %%
X_test
# Out:
#      Marketing expense  Production expense  Multiplex coverage     Budget  \
# 329            21.3448               61.48               0.540  35179.815
# 371           204.6460               91.20               0.369  34529.880
# 219            22.2850               82.78               0.450  35402.015
# 403           516.0340               91.20               0.307  29713.695
# 78             21.1292               80.66               0.563  34618.760
# ..                 ...                 ...                 ...        ...
# 56             20.4110               56.48               0.590  35457.565
# 455           115.0474               91.20               0.287  36246.375
# 60             22.9864               65.26               0.547  31891.255
# 213            22.8104               76.18               0.511  35413.125
# 108            22.5604               72.12               0.480  35963.070
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 329          90.7               7.320                7.460            7.275
# 371         173.5               9.310                9.525            9.320
# 219         165.9               8.175                8.375            8.315
# 403         169.5               9.125                9.310            9.060
# 78          127.2               7.330                7.500            7.450
# ..            ...                 ...                  ...              ...
# 56          109.2               5.340                5.535            5.285
# 455         160.0               8.695                8.790            8.630
# 60          139.7               6.335                6.420            6.235
# 213         105.8               7.945                8.040            7.910
# 108         170.6               8.640                8.910            8.730
#
#      Producer_rating  Critic_rating  Trailer_views  Time_taken  \
# 329            7.515           8.62         483051  111.040000
# 371            9.505           7.96         454281  196.000000
# 219            8.405           8.72         451935  123.200000
# 403            9.100           6.96         384237  157.391498
# 78             7.690           8.26         447528  176.480000
# ..               ...            ...            ...         ...
# 56             5.465           8.54         539589  115.880000
# 455            9.015           6.96         408819  155.640000
# 60             6.560           7.06         465689  157.391498
# 213            8.215           7.28         504226  151.240000
# 108            8.850           7.82         473768  171.920000
#
#      Twitter_hastags  Avg_age_actors  Num_multiplex  3D_available_YES  \
# 329          283.616              53            452             False
# 371          268.000              25            609              True
# 219          263.680              21            561              True
# 403          301.328              40            677              True
# 78           303.392              53            377              True
# ..               ...             ...            ...               ...
# 56           303.952              22            383              True
# 455          282.256              36            620             False
# 60           222.992              30            439             False
# 213          204.496               3            441              True
# 108          203.168              48            502             False
#
#      Genre_Comedy  Genre_Drama  Genre_Thriller
# 329          True        False           False
# 371          True        False           False
# 219          True        False           False
# 403         False        False            True
# 78          False         True           False
# ..            ...          ...             ...
# 56          False         True           False
# 455         False        False            True
# 60          False        False            True
# 213          True        False           False
# 108         False        False           False
#
# [102 rows x 19 columns]

# %% [markdown]
# ## Training Regression Tree

# %%
from sklearn.svm import SVR
svr = SVR(kernel='linear', C = 3000)

# %%
svr.fit(X_train_std, y_train)
# Out:
# SVR(C=3000, kernel='linear')

# %% [markdown]
# ## Predict Values using trained model

# %%
y_test_pred = svr.predict(X_test_std)
y_train_pred = svr.predict(X_train_std)

# %%
y_test_pred
# Out:
# array([54149.04985486, 42108.34471214, 47533.48916052, 17335.56708281,
#        48583.82292107, 39306.44775796, 33505.9535726 , 43171.76493611,
#        29476.26499757, 46980.75731107, 12645.08472007, 38648.42247604,
#        38048.2393664 ,  8415.03656142, 67457.69091145, 62224.2039273 ,
#        38975.54675174, 65880.00221636, 56742.36900529, 42713.82149415,
#        53525.4945361 , 39264.62422239, 41193.07225573, 58209.33323512,
#        42495.88201228, 12132.62441563, 40418.38877099, 29850.91523032,
#        75048.6007429 , 43839.06117388, 36786.86517153, 37330.36790834,
#        37565.19845682, 40538.47149965, 51853.9891749 , 35081.953653  ,
#        25483.31757361, 36025.27585638, 36413.96001024, 36164.40005109,
#        47058.89224016, 45705.55298317, 44210.84051281, 27455.32262481,
#        50732.91083476, 46541.4643388 , 32853.69351743, 40270.99818313,
#        15510.53146757, 52029.40170025, 41465.4276885 , 38769.998203  ,
#        47214.74691353, 68388.92527643, 25170.79907632, 41175.69832861,
#        40899.41103488, 34095.6187623 , 20977.9636645 , 38804.3345306 ,
#        41129.50638139, 41083.49505685, 65425.92618455, 64734.65527107,
#        28281.73281763, 63138.57252568, 37568.72857468, 40005.32896681,
#        42164.20110828, 46623.41251416, 46160.02195304, 49356.99660419,
#        56247.16388057, 60030.58078434, 49366.96696329, 10862.91367164,
#        74305.04922385, 44623.1870363 , 59050.95988711, 37530.90896347,
#        50647.30689611, 43058.54674219, 31784.52915154, 81982.17233805,
#        79971.19671074, 47402.01934047, 50372.39131486, 29749.23771566,
#        50294.7481708 , 37816.3666239 , 33719.5282102 , 34498.87865071,
#        42984.72407916, 59337.27083147, 43237.0100136 , 42010.15292019,
#        -5090.77801028, 52414.30389763, 37462.28212692, 32115.0237617 ,
#        49809.79502581, 48308.98132474])

# %% [markdown]
# ## Model Performance

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mean_squared_error(y_test, y_test_pred)
# Out:
# 161383675.95782796

# %%
r2_score(y_train, y_train_pred)
# Out:
# 0.7110100333340588

# %%
r2_score(y_test, y_test_pred)
# Out:
# 0.49869112364171564

# %% [markdown]
# # Classification Model

# %%
df = pd.read_csv("D:/Machine Learning/Complete Machine Learning with Python/Data Files/4. ST Academy - SVM resource files/Movie_classification.csv", header=0)

# %%
df.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# 0            7.995           7.94         527367          YES      109.60
# 1            7.470           7.44         494055           NO      146.64
# 2            7.515           7.44         547051           NO      147.88
# 3            7.020           8.26         516279          YES      185.36
# 4            7.070           8.26         531448           NO      176.48
#
#    Twitter_hastags     Genre  Avg_age_actors  Num_multiplex  Collection  \
# 0          223.840  Thriller              23            494       48000
# 1          243.456     Drama              42            462       43200
# 2         2022.400    Comedy              38            458       69400
# 3          225.344     Drama              45            472       66800
# 4          225.792     Drama              55            395       72400
#
#    Start_Tech_Oscar
# 0                 1
# 1                 0
# 2                 1
# 3                 1
# 4                 1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Marketing expense    506 non-null    float64
#  1   Production expense   506 non-null    float64
#  2   Multiplex coverage   506 non-null    float64
#  3   Budget               506 non-null    float64
#  4   Movie_length         506 non-null    float64
#  5   Lead_ Actor_Rating   506 non-null    float64
#  6   Lead_Actress_rating  506 non-null    float64
#  7   Director_rating      506 non-null    float64
#  8   Producer_rating      506 non-null    float64
#  9   Critic_rating        506 non-null    float64
#  10  Trailer_views        506 non-null    int64
#  11  3D_available         506 non-null    object
#  12  Time_taken           494 non-null    float64
#  13  Twitter_hastags      506 non-null    float64
#  14  Genre                506 non-null    object
#  15  Avg_age_actors       506 non-null    int64
#  16  Num_multiplex        506 non-null    int64
#  17  Collection           506 non-null    int64
#  18  Start_Tech_Oscar     506 non-null    int64
# dtypes: float64(12), int64(5), object(2)
# memory usage: 75.2+ KB

# %% [markdown]
# ## Missing Value Imputation

# %%
df['Time_taken'].mean()
# Out:
# 157.3914979757085

# %%
df['Time_taken'].fillna(value = df['Time_taken'].mean(), inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Marketing expense    506 non-null    float64
#  1   Production expense   506 non-null    float64
#  2   Multiplex coverage   506 non-null    float64
#  3   Budget               506 non-null    float64
#  4   Movie_length         506 non-null    float64
#  5   Lead_ Actor_Rating   506 non-null    float64
#  6   Lead_Actress_rating  506 non-null    float64
#  7   Director_rating      506 non-null    float64
#  8   Producer_rating      506 non-null    float64
#  9   Critic_rating        506 non-null    float64
#  10  Trailer_views        506 non-null    int64
#  11  3D_available         506 non-null    object
#  12  Time_taken           506 non-null    float64
#  13  Twitter_hastags      506 non-null    float64
#  14  Genre                506 non-null    object
#  15  Avg_age_actors       506 non-null    int64
#  16  Num_multiplex        506 non-null    int64
#  17  Collection           506 non-null    int64
#  18  Start_Tech_Oscar     506 non-null    int64
# dtypes: float64(12), int64(5), object(2)
# memory usage: 75.2+ KB

# %% [markdown]
# ## Dummy variable Creation

# %%
df.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# 0            7.995           7.94         527367          YES      109.60
# 1            7.470           7.44         494055           NO      146.64
# 2            7.515           7.44         547051           NO      147.88
# 3            7.020           8.26         516279          YES      185.36
# 4            7.070           8.26         531448           NO      176.48
#
#    Twitter_hastags     Genre  Avg_age_actors  Num_multiplex  Collection  \
# 0          223.840  Thriller              23            494       48000
# 1          243.456     Drama              42            462       43200
# 2         2022.400    Comedy              38            458       69400
# 3          225.344     Drama              45            472       66800
# 4          225.792     Drama              55            395       72400
#
#    Start_Tech_Oscar
# 0                 1
# 1                 0
# 2                 1
# 3                 1
# 4                 1

# %%
df = pd.get_dummies(df, columns = ["3D_available", "Genre"], drop_first = True)

# %%
df.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  ...  Time_taken  Twitter_hastags  \
# 0            7.995           7.94  ...      109.60          223.840
# 1            7.470           7.44  ...      146.64          243.456
# 2            7.515           7.44  ...      147.88         2022.400
# 3            7.020           8.26  ...      185.36          225.344
# 4            7.070           8.26  ...      176.48          225.792
#
#    Avg_age_actors  Num_multiplex  Collection  Start_Tech_Oscar  \
# 0              23            494       48000                 1
# 1              42            462       43200                 0
# 2              38            458       69400                 1
# 3              45            472       66800                 1
# 4              55            395       72400                 1
#
#    3D_available_YES  Genre_Comedy  Genre_Drama  Genre_Thriller
# 0              True         False        False            True
# 1             False         False         True           False
# 2             False          True        False           False
# 3              True         False         True           False
# 4             False         False         True           False
#
# [5 rows x 21 columns]

# %% [markdown]
# ## X-y Split

# %%
X = df.loc[:, df.columns!="Start_Tech_Oscar"]
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
X.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views  Time_taken  Twitter_hastags  \
# 0            7.995           7.94         527367      109.60          223.840
# 1            7.470           7.44         494055      146.64          243.456
# 2            7.515           7.44         547051      147.88         2022.400
# 3            7.020           8.26         516279      185.36          225.344
# 4            7.070           8.26         531448      176.48          225.792
#
#    Avg_age_actors  Num_multiplex  Collection  3D_available_YES  Genre_Comedy  \
# 0              23            494       48000              True         False
# 1              42            462       43200             False         False
# 2              38            458       69400             False          True
# 3              45            472       66800              True         False
# 4              55            395       72400             False         False
#
#    Genre_Drama  Genre_Thriller
# 0        False            True
# 1         True           False
# 2        False           False
# 3         True           False
# 4         True           False

# %%
X.shape
# Out:
# (506, 20)

# %%
y = df["Start_Tech_Oscar"]
type(y)
# Out:
# pandas.core.series.Series

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: Start_Tech_Oscar, dtype: int64

# %%
y.shape
# Out:
# (506,)

# %% [markdown]
# ## Test Train Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
X_train.head()
# Out:
#      Marketing expense  Production expense  Multiplex coverage     Budget  \
# 220            27.1618               67.40               0.493  38612.805
# 71             23.1752               76.62               0.587  33113.355
# 240            22.2658               64.86               0.572  38312.835
# 6              21.7658               70.74               0.476  33396.660
# 417           538.8120               91.20               0.321  29463.720
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 220         162.0               8.485                8.640            8.485
# 71           91.0               7.280                7.400            7.290
# 240         127.8               6.755                6.935            6.800
# 6           140.1               7.065                7.265            7.150
# 417         162.6               9.135                9.305            9.095
#
#      Producer_rating  Critic_rating  Trailer_views  Time_taken  \
# 220            8.670           8.52         480270      174.68
# 71             7.455           8.16         491978      200.68
# 240            6.840           8.68         470107      204.80
# 6              7.400           8.96         459241      139.16
# 417            9.165           6.96         302776      172.16
#
#      Twitter_hastags  Avg_age_actors  Num_multiplex  Collection  \
# 220          224.272              23            536       53400
# 71           263.472              46            400       43400
# 240          224.320              24            387       54000
# 6            243.664              41            522       45800
# 417          301.664              60            589       20800
#
#      3D_available_YES  Genre_Comedy  Genre_Drama  Genre_Thriller
# 220             False         False        False            True
# 71              False         False        False           False
# 240              True          True        False           False
# 6                True         False        False            True
# 417              True         False        False           False

# %%
X_train.shape
# Out:
# (404, 20)

# %%
X_test.shape
# Out:
# (102, 20)

# %% [markdown]
# ## Standardizing Data

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler().fit(X_train)

# %%
X_train_std = sc.transform(X_train)

# %%
X_test_std = sc.transform(X_test)

# %%
X_test_std
# Out:
# array([[-0.40835869, -1.12872913,  0.83336883, ...,  1.50268577,
#         -0.48525664, -0.75225758],
#        [ 0.71925111,  0.9988844 , -0.65283979, ...,  1.50268577,
#         -0.48525664, -0.75225758],
#        [-0.40257488,  0.39610829,  0.05115377, ...,  1.50268577,
#         -0.48525664, -0.75225758],
#        ...,
#        [-0.3982601 , -0.85812418,  0.89420778, ..., -0.66547513,
#         -0.48525664,  1.3293319 ],
#        [-0.39934279, -0.07637654,  0.58132175, ...,  1.50268577,
#         -0.48525664, -0.75225758],
#        [-0.40088071, -0.36702631,  0.31189212, ..., -0.66547513,
#         -0.48525664, -0.75225758]])

# %% [markdown]
# ## Training SVM

# %%
from sklearn import svm

# %%
clf_svm_l = svm.SVR(kernel='linear', C = 0.01)
clf_svm_l.fit(X_train_std, y_train)
# Out:
# SVR(C=0.01, kernel='linear')

# %% [markdown]
# ## Predict Values using Trained model

# %%
y_train_pred = clf_svm_l.predict(X_train_std)
y_test_pred =clf_svm_l.predict(X_test_std)

# %%
y_test
# Out:
# 329    0
# 371    1
# 219    0
# 403    0
# 78     0
#       ..
# 56     1
# 455    1
# 60     1
# 213    0
# 108    1
# Name: Start_Tech_Oscar, Length: 102, dtype: int64

# %%
y_test_pred
# Out:
# array([ 0.74180262,  1.12287553,  0.59341578,  0.29649027,  0.72135016,
#         0.30438042,  0.56218095,  0.58795202,  0.27379588,  0.4672563 ,
#         0.27282198,  0.35199932,  0.27882356,  0.5927423 ,  1.01122726,
#         0.82298605,  0.25664706,  0.65803973,  0.80726736,  0.27335658,
#         0.43483528,  0.1214996 ,  0.7508684 ,  0.50576013,  0.18735644,
#         0.6308777 ,  0.39398486,  0.92909135,  0.63932477,  0.21629911,
#         0.91378757,  0.90640891,  0.31348602,  0.58869509,  0.41898046,
#         0.45174502,  0.38426505,  1.30065113,  0.11505529,  0.44926293,
#         0.54055423,  0.61080023,  0.2018567 ,  0.3258399 ,  0.29937005,
#         0.66880161,  0.84833363,  0.50935233,  0.86170835,  0.58711536,
#         0.03242697,  0.74023931,  0.56426969,  0.74539693,  0.39704698,
#         1.00327664,  0.67404295,  0.70474666, -0.02684059,  0.67999885,
#         0.70639726,  0.29898224,  0.49254519,  0.60617629,  0.69722476,
#         0.33722601,  0.57309446,  0.82097875,  1.00676441,  0.3397913 ,
#         0.30342468,  0.46913579,  0.00232432,  0.17553088,  0.54278568,
#         0.63522812,  0.80003875,  0.6910314 ,  0.6417935 ,  1.03983154,
#         0.7533907 ,  0.43584447,  0.65112965,  0.92979338,  0.67593748,
#         0.49211394, -0.09153107,  0.19711761,  0.74266752,  0.48673459,
#         0.92151829,  0.3235697 ,  0.68629075,  0.25441191,  0.19689902,
#         0.84739411,  1.24314338,  0.94706332,  0.28494631,  0.48605372,
#         0.52216453,  0.24092227])

# %% [markdown]
# ## Model Performance

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
confusion_matrix(y_test, y_test_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 confusion_matrix(y_test, y_test_pred)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:319, in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     224 @validate_params(
#     225     {
#     226         "y_true": ["array-like"],
#    (...)
#     235     y_true, y_pred, *, labels=None, sample_weight=None, normalize=None
#     236 ):
#     237     """Compute confusion matrix to evaluate the accuracy of a classification.
#     238
#     239     By definition a confusion matrix :math:`C` is such that :math:`C_{i, j}`
#    (...)
#     317     (0, 2, 1, 1)
#     318     """
# --> 319     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     320     if y_type not in ("binary", "multiclass"):
#     321         raise ValueError("%s is not supported" % y_type)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:94, in _check_targets(y_true, y_pred)
#      91     y_type = {"multiclass"}
#      93 if len(y_type) > 1:
# ---> 94     raise ValueError(
#      95         "Classification metrics can't handle a mix of {0} and {1} targets".format(
#      96             type_true, type_pred
#      97         )
#      98     )
#     100 # We can't have more than one value on y_type => The set is no more needed
#     101 y_type = y_type.pop()
#
# ValueError: Classification metrics can't handle a mix of binary and continuous targets

# %%
accuracy_score(y_test, y_test_pred)

# %%
clf_svm_l.n_support_

# %% [markdown]
# # Grid Search

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {'C' : (0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1, 5, 10, 50, 100, 500, 1000)}

# %%
clf_svm_l = svm.SVC(kernel='poly')

# %%
svm_grid_lin = GridSearchCV(clf_svm_l, params, n_jobs = -1, 
                            cv = 10, verbose=1, scoring='accuracy')

# %%
svm_grid_lin.fit(X_train_std, y_train)
# Out:
# Fitting 10 folds for each of 13 candidates, totalling 130 fits
# GridSearchCV(cv=10, estimator=SVC(kernel='poly'), n_jobs=-1,
#              param_grid={'C': (0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1, 5, 10, 50,
#                                100, 500, 1000)},
#              scoring='accuracy', verbose=1)

# %%
svm_grid_lin.best_params_
# Out:
# {'C': 1}

# %%
linsvm_clf = svm_grid_lin.best_estimator_

# %%
accuracy_score(y_test, linsvm_clf.predict(X_test_std))
# Out:
# 0.5980392156862745

# %% [markdown]
# # Polynomial

# %%
clf_svm_p3 = svm.SVC(kernel='poly', degree=2, C = 0.1)
clf_svm_p3.fit(X_train_std, y_train)
# Out:
# SVC(C=0.1, degree=2, kernel='poly')

# %%
y_train_pred = clf_svm_p3.predict(X_train_std)
y_test_pred = clf_svm_p3.predict(X_test_std)

# %%
accuracy_score(y_test, y_test_pred)
# Out:
# 0.5588235294117647

# %%
clf_svm_p3.n_support_
# Out:
# array([185, 194])

# %% [markdown]
# # Radial

# %%
clf_svm_r = svm.SVC(kernel='rbf', gamma=0.5, C=10)
clf_svm_r.fit(X_train_std, y_train)
# Out:
# SVC(C=10, gamma=0.5)

# %%
y_train_pred = clf_svm_r.predict(X_train_std)
y_test_pred = clf_svm_r.predict(X_test_std)

# %%
accuracy_score(y_test, y_test_pred)
# Out:
# 0.6176470588235294

# %%
clf_svm_r.n_support_
# Out:
# array([186, 218])

# %% [markdown]
# ## Radial Grid

# %%
params = {'C' : (0.01, 0.05, 0.1, 0.5, 1, 5, 10, 50),
        'gamma' : (0.001, 0.01, 0.1, 0.5, 1)}

# %%
clf_svm_r = svm.SVC(kernel = 'rbf')

# %%
svm_grid_rad = GridSearchCV(clf_svm_r, params, n_jobs=-1,
                           cv=3, verbose=1, scoring='accuracy')

# %%
svm_grid_rad.fit(X_train_std, y_train)
# Out:
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# GridSearchCV(cv=3, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': (0.01, 0.05, 0.1, 0.5, 1, 5, 10, 50),
#                          'gamma': (0.001, 0.01, 0.1, 0.5, 1)},
#              scoring='accuracy', verbose=1)

# %%
svm_grid_rad.best_params_
# Out:
# {'C': 50, 'gamma': 0.001}

# %%
radsvm_clf = svm_grid_rad.best_estimator_

# %%
accuracy_score(y_test, radsvm_clf.predict(X_test_std))
# Out:
# 0.6176470588235294
